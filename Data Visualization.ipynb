# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree
from sklearn import tree, svm, linear_model
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
df=pd.read_csv('D.csv')

# %%
df[df < 0] = np.nan

# %%
df= df[[
    'X2TXMTH',
    'C2AVGACTENG',
'X2PAREDU',
'X2RACE',
'X2SEX',
'X4EVERDROP',
'X4HSCOMPSTAT',
'X3TGPAWGT',
'X3TGPATOT',
'X3TCREDTOT',
'X3TCREDACAD',
'X3TCREDMTSC',
'X3TGPAACAD',
'X3TGPASTEM',
'X3TGPASOCST',
'X3DROPOUTTIME',
'X3CONTROL',    
'X4EVRAPPCLG']]

# %%
df.dropna(inplace=True)

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df["X4EVRAPPCLG"])

# set x/y labels and plot title
plt.pyplot.xlabel("X3TCREDTOT")
plt.pyplot.ylabel("count")
plt.pyplot.title("Applied or registered to college")
# Out:
# Text(0.5, 1.0, 'Applied or registered to college')

# %%
import matplotlib.pyplot as plt
sns.barplot(x=df['X2SEX'].value_counts().index,y=df['X2SEX'].value_counts().values)
plt.title('Genders other rate')
plt.ylabel('Rates')
plt.legend(loc=0)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(7,7))
sns.barplot(x=df['X2RACE'].value_counts().index,
              y=df['X2RACE'].value_counts().values)
plt.xlabel('Race/Ethnicity')
plt.ylabel('Frequency')
plt.title('Show of Race/Ethnicity Bar Plot')
plt.show()

# %%
df['X2PAREDU'].value_counts()
# Out:
# 5.0    1226
# 2.0     957
# 6.0     715
# 4.0     624
# 7.0     411
# 3.0     130
# 1.0     102
# Name: X2PAREDU, dtype: int64

# %% [markdown]
# plt.figure(figsize=(10,7))
# sns.barplot(x = "X2PAREDU", y = "X3TGPATOT", hue = "X2SEX", df = df)
# plt.xticks(rotation=45)
# plt.show()

# %%
import matplotlib.pyplot as plt
sns.catplot(x="X2SEX", y="X3TGPATOT",
                 hue="X4EVERDROP",
                 data=df, kind="bar")
plt.title('for drop, Gender & GPA')
plt.show()

# %%
import matplotlib as plt
from matplotlib import pyplot

ax = sns.pointplot(x="X3TGPATOT", y= 'X3TGPASTEM', hue="X2SEX",data=df,markers=["o", "x"],linestyles=["-", "--"])
#plt.xticks(rotation=90)

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df["X2TXMTH"])

# set x/y labels and plot title
plt.pyplot.xlabel("X2TXMTH")
plt.pyplot.ylabel("count")
plt.pyplot.title("Math score")
# Out:
# Text(0.5, 1.0, 'Math score')

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df["C2AVGACTENG"])

# set x/y labels and plot title
plt.pyplot.xlabel("C2AVGACTENG")
plt.pyplot.ylabel("count")
plt.pyplot.title("English score")
# Out:
# Text(0.5, 1.0, 'English score')

# %%
import matplotlib as plt
from matplotlib import pyplot
sns.boxplot(x=df['X2SEX'],y=df['X3TGPATOT'])

# %%
import matplotlib as plt
from matplotlib import pyplot
sns.boxplot(x=df['X4EVRAPPCLG'],y=df['X3TGPATOT'])

# %%
import matplotlib as plt
from matplotlib import pyplot
sns.boxplot(x=df['X2RACE'],y=df['X3TGPATOT'])
plt.xticks(rotation=90)
sns.swarmplot(x=df['X2RACE'],y=df['X3TGPATOT'],color=".25")
plt.xticks(rotation=90)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-412749a78ff4> in <module>
#       2 from matplotlib import pyplot
#       3 sns.boxplot(x=df['X2RACE'],y=df['X3TGPATOT'])
# ----> 4 plt.xticks(rotation=90)
#       5 sns.swarmplot(x=df['X2RACE'],y=df['X3TGPATOT'],color=".25")
#       6 plt.xticks(rotation=90)
#
# AttributeError: module 'matplotlib' has no attribute 'xticks'

# %%
sns.swarmplot(x=df['X4EVRAPPCLG'],y=df['X2TXMTH'])

# %%
sns.swarmplot(x=df['X4EVRAPPCLG'],y=df['X2TXMTH'],hue=df['X2SEX'])

# %%
sns.swarmplot(x=df['X4EVRAPPCLG'],y=df['X2TXMTH'],hue=df['X2RACE'],palette='Set2',dodge=True)

# %%
sns.boxplot(x=df['X4EVRAPPCLG'],y=df['X3TCREDTOT'],whis=np.inf)
sns.swarmplot(x=df['X4EVRAPPCLG'],y=df['X3TCREDTOT'],color='.2')

# %%
sns.lineplot(x='X3TGPATOT',y='X3TGPASTEM',data=df)

# %%
sns.lineplot(x='X3TGPATOT',y='X3TGPASTEM',hue='X4EVRAPPCLG',data=df)
